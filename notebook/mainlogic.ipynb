# %% [markdown]
# <a href="https://colab.research.google.com/github/HakureiPOI/llm-stockrec/blob/main/notebook/mainlogic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HakureiPOI

# %% [markdown]
# ---
#
# ## Part1. 行情抓取逻辑
